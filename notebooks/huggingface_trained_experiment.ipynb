# %%
# based on https://colab.research.google.com/github/dvgodoy/FineTuningLLMs/blob/main/Chapter0.ipynb#scrollTo=3edc24ed

# !pip install transformers==4.46.2 peft==0.13.2 accelerate==1.1.1 trl==0.12.1 huggingface-hub==0.26.2 numpy==1.26.4
# !pip install datasets bitsandbytes trl dagshub pandas evaluate rouge_score bert_score mlflow


import os
import torch
from datasets import load_dataset
from peft import get_peft_model, LoraConfig, prepare_model_for_kbit_training
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from trl import SFTConfig, SFTTrainer


# We quantize the base model so it requires less GPU's RAM
bnb_config = BitsAndBytesConfig(
   load_in_4bit=True,
   bnb_4bit_quant_type="nf4",
   bnb_4bit_use_double_quant=True,
   bnb_4bit_compute_dtype=torch.float32
)
repo_id = 'CYFRAGOVPL/Llama-PLLuM-8B-instruct'
# Load the model and pass quantization config
model = AutoModelForCausalLM.from_pretrained(repo_id,
                                             device_map="cuda:0",
                                             quantization_config=bnb_config
)

# Linear4bit in the quantized model can be used for inference but not for training
# We need to find a way to go around this
# We will use Low-Rank Adapters (LoRA)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
# improves numerical stability during training
model = prepare_model_for_kbit_training(model)

config = LoraConfig(
    r=8,                   # the rank of the adapter, the lower the fewer parameters you'll need to train
    lora_alpha=16,         # multiplier, usually 2*r
    bias="none",           # BEWARE: training biases *modifies* base model's behavior
    lora_dropout=0.05,
    task_type="CAUSAL_LM",
    # Newer models, such as Phi-3 at time of writing, may require
    # manually setting target modules
    target_modules=['o_proj', 'qkv_proj', 'gate_up_proj', 'down_proj'],
)

# apply the configuration to the quantized base model
model = get_peft_model(model, config)
model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128258, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaSdpaAttention(
#               (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#               (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.05, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=14336, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128258, bias=False)
#     )
#   )
# )

# %%
trainable_parms, tot_parms = model.get_nb_trainable_parameters()
print(f'Trainable parameters:             {trainable_parms/1e6:.2f}M')
print(f'Total parameters:                 {tot_parms/1e6:.2f}M')
print(f'Fraction of trainable parameters: {100*trainable_parms/tot_parms:.2f}%')
# Out:
# Trainable parameters:             6.82M
# Total parameters:                 8037.09M
# Fraction of trainable parameters: 0.08%

# %%
from dagshub.data_engine import datasources
import pandas as pd

ds = datasources.get("informal2formal/mlflow", "synthetic_data_source")
ds.head().dataframe
# Out:
# Accessing as yanvoi
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                path  datapoint_id  \
# 0  informal_formal_synthetic_v1.csv      86087877
#
#                                 dagshub_download_url  media type     size
# 0  https://dagshub.com/api/v1/repos/informal2form...  text/plain  1221781

# %%
dataset_uri = ds.head().dataframe["dagshub_download_url"].values[0]
df = pd.read_csv(dataset_uri)
df.head()
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   zdanie_nieformalne  \
# 0  Nie cierpię, jak wchodzę do przymierzalni w sk...
# 1  Trzeba zakasać rękawy i zapierdalać, jeśli chc...
# 2  Muszę się w końcu zabrać za naukę obsługi jaki...
# 3  Weź się w końcu ogarnij z tym swoim ciągłym kr...
# 4  Wpadnij do mnie na chwilę po pracy, musimy prz...
#
#                                      zdanie_formalne       model generator  \
# 0  Odczuwam dyskomfort, gdy wchodząc do przymierz...  gemini-2.5      seba
# 1  Konieczne jest wzmożenie wysiłków i intensyfik...  gemini-2.5    jedrek
# 2  Postanowiłem rozpocząć naukę obsługi jednego z...  gemini-2.5      seba
# 3  Apeluję o zmianę Pana/Pani postawy i zaprzesta...  gemini-2.5    jedrek
# 4  Zapraszam do siebie na chwilę po zakończeniu p...  gemini-2.5    jedrek
#
#    split
# 0  train
# 1  train
# 2  train
# 3  train
# 4  train

# %%
df_train = df[df['split'] == 'train'][['zdanie_nieformalne', 'zdanie_formalne']]
df_val = df[df['split'] == 'val'][['zdanie_nieformalne', 'zdanie_formalne']]
df_test = df[df['split'] == 'test'][['zdanie_nieformalne', 'zdanie_formalne']]

# %%
from datasets import Dataset

train_dataset = Dataset.from_pandas(df_train)
val_dataset = Dataset.from_pandas(df_val)
test_dataset = Dataset.from_pandas(df_test)

train_dataset = train_dataset.select(range(750))

# %%
# Promp which will be used for the training and inference
# It serves the purpose of instructing the model what to do
system_message = 'Dokonaj konwersji poniższego tekstu nieformalnego na tekst w stylu formalnym z zachowaniem wszystkich informacji'

# this format is required by the training framework
def format_dataset(examples):
    def format_single(prompt, completion):
        messages = []
        messages.append({"role": "system", "content": system_message})
        messages.append({"role": "user", "content": prompt})
        messages.append({"role": "assistant", "content": completion})
        return messages

    if isinstance(examples["zdanie_nieformalne"], list):
        return {"messages": [format_single(p, c) for p, c in zip(examples["zdanie_nieformalne"], examples["zdanie_formalne"])]}

    return {"messages": format_single(examples["zdanie_nieformalne"], examples["zdanie_formalne"])}

# %%
train_dataset = train_dataset.map(format_dataset).remove_columns(['zdanie_nieformalne', 'zdanie_formalne'])
val_dataset = val_dataset.map(format_dataset).remove_columns(['zdanie_nieformalne', 'zdanie_formalne'])
test_dataset = test_dataset.map(format_dataset).remove_columns(['zdanie_nieformalne', 'zdanie_formalne'])

train_dataset
# Out:
# Map:   0%|          | 0/750 [00:00<?, ? examples/s]
# Map:   0%|          | 0/350 [00:00<?, ? examples/s]
# Map:   0%|          | 0/700 [00:00<?, ? examples/s]
# Dataset({
#     features: ['__index_level_0__', 'messages'],
#     num_rows: 750
# })

# %%
# load tokenizer from the base model
tokenizer = AutoTokenizer.from_pretrained(repo_id)
tokenizer.chat_template
# Out:
# "{%- if messages[0]['role'] == 'system' %}\n    {%- set system_message = messages[0]['content'] %}\n    {%- set loop_messages = messages[1:] %}\n{%- else %}\n    {%- set loop_messages = messages %}\n{%- endif %}\n\n{{- bos_token }}\n{%- for message in loop_messages %}\n    {%- if (message['role'] == 'user') != (loop.index0 % 2 == 0) %}\n        {{- raise_exception('After the optional system message, conversation roles must alternate user/assistant/user/assistant/...') }}\n    {%- endif %}\n    {%- if message['role'] == 'user' %}\n        {%- if loop.first and system_message is defined %}\n            {{- '[INST]' + system_message + '\\n\\n' + message['content'] + '[/INST]' }}\n        {%- else %}\n            {{- '[INST]' + message['content'] + '[/INST]' }}\n        {%- endif %}\n    {%- elif message['role'] == 'assistant' %}\n        {{- message['content'] + eos_token}}\n    {%- else %}\n        {{- raise_exception('Only user and assistant roles are supported, with the exception of an initial optional system message!') }}\n    {%- endif %}\n{%- endfor %}\n"

# %%
if tokenizer.pad_token is None:
    tokenizer.add_special_tokens({'pad_token': '[PAD]'})
model.resize_token_embeddings(len(tokenizer))  # IMPORTANT: resize model's embeddings
# Out:
# Embedding(128258, 4096)

# %%
sft_config = SFTConfig(
    ## GROUP 1: Memory usage
    # These arguments will squeeze the most out of your GPU's RAM
    # Checkpointing
    gradient_checkpointing=True,
    # this saves a LOT of memory
    # Set this to avoid exceptions in newer versions of PyTorch
    gradient_checkpointing_kwargs={'use_reentrant': False},
    # Gradient Accumulation / Batch size
    # Actual batch (for updating) is same (1x) as micro-batch size
    gradient_accumulation_steps=4,
    # The initial (micro) batch size to start off with
    per_device_train_batch_size=2,
    # If batch size would cause OOM, halves its size until it works
    auto_find_batch_size=True,

    ## dataset-related
    max_seq_length=128,

    # packing a dataset means no padding is needed
    packing=False,

    # training parameters
    num_train_epochs=2,
    learning_rate=3e-4,

    # 8-bit Adam optimizer
    optim='paged_adamw_8bit',

    # Logging parameters
    logging_steps=10,
    logging_dir='./logs',
    output_dir='./informal-to-formal-text-converter',
    report_to='mlflow'
)

# %%
trainer = SFTTrainer(
    model=model,
    processing_class=tokenizer,
    args=sft_config,
    train_dataset=train_dataset,
    eval_dataset = val_dataset,
)
# Out:
# Map:   0%|          | 0/750 [00:00<?, ? examples/s]
# Map:   0%|          | 0/350 [00:00<?, ? examples/s]

# %%
dl = trainer.get_train_dataloader()
batch = next(iter(dl))

# %%
batch['input_ids'][0], batch['labels'][0]
# Out:
# (tensor([128000, 128256,     35,    564,    263,   1662,  16947,  24584,   7910,
#             281,  21446,   6077,  14694,  13546,  43185,  61782,  11568,    630,
#             278,  53199,   4415,  73678,    289,  49304,     84,  16287,  49221,
#            1167,  97912,    363,  97408,  45927,  71876,   6179,  34478,    271,
#              50,   4697,   1412,   1662,    357,    661,     11,  11568,    293,
#           62151,  40611,   3625,     89,  14088,    336,    602,   7019,   1142,
#              89,    289,  15593,  19699,  20811,  34227,  77910,  90941,   1910,
#             648,     11,  24230,    523,   1634,     89,  12951,  39852,  21127,
#            7886,     11,   1167,  10830,    561,    503,   5985,  25398,  76411,
#            7886,    602,   2709,     89,  22227,  10196,   7886,     11,    293,
#           62151,  40611,  45607,    336,    602,  15036,   4697,    266,     86,
#             311,   1167, 111321,   5985,     13, 128257,  10835,    301,   9832,
#            5267,    297,    656,  60013,   4458,  23762,  25898,    602,  11018,
#              86,    351,   5267,    289,  63080,    490,    664,  36900,   6705,
#           25506,  34478], device='cuda:0'),
#  tensor([128000, 128256,     35,    564,    263,   1662,  16947,  24584,   7910,
#             281,  21446,   6077,  14694,  13546,  43185,  61782,  11568,    630,
#             278,  53199,   4415,  73678,    289,  49304,     84,  16287,  49221,
#            1167,  97912,    363,  97408,  45927,  71876,   6179,  34478,    271,
#              50,   4697,   1412,   1662,    357,    661,     11,  11568,    293,
#           62151,  40611,   3625,     89,  14088,    336,    602,   7019,   1142,
#              89,    289,  15593,  19699,  20811,  34227,  77910,  90941,   1910,
#             648,     11,  24230,    523,   1634,     89,  12951,  39852,  21127,
#            7886,     11,   1167,  10830,    561,    503,   5985,  25398,  76411,
#            7886,    602,   2709,     89,  22227,  10196,   7886,     11,    293,
#           62151,  40611,  45607,    336,    602,  15036,   4697,    266,     86,
#             311,   1167, 111321,   5985,     13, 128257,  10835,    301,   9832,
#            5267,    297,    656,  60013,   4458,  23762,  25898,    602,  11018,
#              86,    351,   5267,    289,  63080,    490,    664,  36900,   6705,
#           25506,  34478], device='cuda:0'))

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='129' max='186' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [129/186 39:24 < 17:41, 0.05 it/s, Epoch 1.37/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.429200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.095300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.010400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.971800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.979400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.938300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.946500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.901900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.900800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.898700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.835700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.814100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='186' max='186' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [186/186 57:18, Epoch 1/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.429200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.095300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.010400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.971800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.979400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.938300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.946500</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.901900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.900800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.898700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.835700</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.814100</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.787400</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.794500</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.803700</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.802800</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.781300</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.779600</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=186, training_loss=0.9105605566373436, metrics={'train_runtime': 3455.2207, 'train_samples_per_second': 0.434, 'train_steps_per_second': 0.054, 'total_flos': 8229330929025024.0, 'train_loss': 0.9105605566373436, 'epoch': 1.9866666666666668})

# %%
def gen_prompt(tokenizer, sentence):
    messages = []
    messages.append({"role": "system", "content": system_message})
    messages.append({"role": "user", "content": sentence})

    prompt = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True
    )
    return prompt

# %%
def generate(model, tokenizer, prompt, max_new_tokens=128, skip_special_tokens=False):
    tokenized_input = tokenizer(prompt, add_special_tokens=False, return_tensors="pt").to(model.device)

    model.eval()
    generation_output = model.generate(**tokenized_input,
                                       eos_token_id=tokenizer.eos_token_id,
                                       max_new_tokens=max_new_tokens)

    output = tokenizer.batch_decode(generation_output,
                                    skip_special_tokens=skip_special_tokens)
    return output[0].split("[/INST]")[-1].replace("<|end_of_text|>", "")

def formalize(text):
  prompt = gen_prompt(tokenizer, text)
  return generate(model, tokenizer, prompt)

# %%
trainer.save_model('informal-to-formal-text-converter-model')

# %%
evaluation_texts = [
    "Mógłbyś mi przypomnieć, jaki był deadline na oddanie tego raportu? Coś mi świta, że to było w tym tygodniu.",
    "Trzeba opierdolić tych z supportu, bo czekam na odpowiedź już trzeci dzień, a problem dalej nierozwiązany.",
    "Nie chce mi się iść do pracy w chuj dzisiaj. Mógłbyś zrobić moje taski za mnie? pls ziom, poratuj"
]

# %%
for text in evaluation_texts:
  print(formalize(text))
# Out:
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Czy mógłby Pan/Pani przypomnieć mi datę graniczną (deadline) oddania raportu? Wydaje mi się, że termin ten przypadał w tym tygodniu.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Należy skontaktować się z działem obsługi klienta i wyrazić swoje niezadowolenie z braku reakcji na zgłoszenie problemu, który pozostaje nierozwiązany od trzech dni.
# Niestety, dzisiaj nie mam motywacji do pracy. Czy mógłbyś/mogłabyś zająć się moimi zadaniami za mnie? Bardzo proszę o pomoc.

# %%
import pandas as pd
from tqdm.notebook import tqdm
from informal_to_formal.evaluation.evaluator import Evaluator

# %%
def evaluate_language_model(
        pred: list[str], target: list[str]
    ) -> tuple[pd.DataFrame, dict]:
    evaluator = Evaluator(pd.DataFrame({
        "pred": pred,
        "target": target,
    }))
    evaluate_df_metrics, avg_metrics = evaluator.evaluate()
    return evaluate_df_metrics, avg_metrics

# %%
# limit due to Collab resources & time restrictions
TEST_DATA_LIMIT=10
test_list_pred = df_test['zdanie_nieformalne'].tolist()[:TEST_DATA_LIMIT]
test_list_target = df_test['zdanie_formalne'].tolist()[:TEST_DATA_LIMIT]

# OOM for batch predictions, insufficent Collab resources
# base_model_predictions = generate_language_model_batch_output(test_list, model, tokenizer, alpaca_prompt_pl, batch_size=4)

base_model_predictions = [
    formalize(input)
    for input in tqdm(test_list_pred)
]
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
from informal_to_formal.evaluation import Evaluator


def evaluate_language_model(
        pred: list[str], target: list[str]
    ) -> tuple[pd.DataFrame, dict]:
    evaluator = Evaluator(pd.DataFrame({
        "pred": pred,
        "target": target,
    }))
    evaluate_df_metrics, avg_metrics = evaluator.evaluate()
    return evaluate_df_metrics, avg_metrics

evaluate_df_metrics, avg_metrics = evaluate_language_model(
    base_model_predictions, test_list_target
)
avg_metrics
# Out:
# Computing ROUGE scores:   0%|          | 0/10 [00:00<?, ?it/s]
# Computing ROUGE scores:  20%|██        | 2/10 [00:00<00:00, 11.39it/s]
# Computing ROUGE scores:  40%|████      | 4/10 [00:00<00:00,  8.34it/s]
# Computing ROUGE scores:  50%|█████     | 5/10 [00:00<00:00,  6.58it/s]
# Computing ROUGE scores:  60%|██████    | 6/10 [00:00<00:00,  6.62it/s]
# Computing ROUGE scores:  70%|███████   | 7/10 [00:01<00:00,  6.40it/s]
# Computing ROUGE scores:  80%|████████  | 8/10 [00:01<00:00,  6.54it/s]
# Computing ROUGE scores:  90%|█████████ | 9/10 [00:01<00:00,  6.36it/s]
# Computing ROUGE scores: 100%|██████████| 10/10 [00:01<00:00,  6.05it/s]
#
# Computing BERT scores:   0%|          | 0/10 [00:00<?, ?it/s]
# Computing BERT scores:  20%|██        | 2/10 [00:04<00:19,  2.49s/it]
# Computing BERT scores: 100%|██████████| 10/10 [00:05<00:00,  1.92it/s]
# {'rouge1': 0.41000718192139907,
#  'rouge2': 0.23872723579235725,
#  'rougeL': 0.35398275752130354,
#  'bert_precision': 0.7782713532447815,
#  'bert_recall': 0.7836599528789521,
#  'bert_f1': 0.7807435810565948}

# %%
evaluate_df_metrics.sort_values(by='bert_f1')
# Out:
#                                                 pred  \
# 6                Ta pogoda jest niezwykle uciążliwa.
# 7  Nie ukrywam, że jestem zirytowany częstymi tel...
# 4  Nowy program telewizyjny, w którym celebryci u...
# 8  Nowa roślina owadożerna, którą posiadam, jest ...
# 0  Kontaktujące się pukanie do drzwi przymierzaln...
# 2  Nowy serial political fiction charakteryzuje s...
# 5  Wyzwania publikowane na Facebooku, polegające ...
# 3  Nowo zakupiony masażer do stóp, wyposażony w f...
# 9  Powinniśmy rozważyć zakup nowych, ergonomiczny...
# 1  Nowa funkcja w nawigacji samochodowej, informu...
#
#                                               target    rouge1    rouge2  \
# 6               Ta pogoda powoduje u mnie ból głowy.  0.266667  0.153846
# 7  Nachalne telefony od telemarketerów oferującyc...  0.272727  0.069767
# 4  Nowy program telewizyjny, w którym celebryci p...  0.368932  0.217822
# 8  Moja nowa roślina owadożerna okazała się fascy...  0.302326  0.142857
# 0  Pukanie do drzwi przymierzalni i zadawanie pyt...  0.523077  0.253968
# 2  Nowy serial z gatunku political fiction charak...  0.311688  0.186667
# 5  Wyzwania internetowe krążące na Facebooku, pol...  0.333333  0.113636
# 3  Nowy masażer do stóp wyposażony w funkcje podg...  0.505051  0.412371
# 9  Powinniśmy rozważyć inwestycję w bardziej ergo...  0.576271  0.315789
# 1  Nowa funkcja w systemie nawigacji samochodowej...  0.640000  0.520548
#
#      rougeL  bert_precision  bert_recall   bert_f1
# 6  0.266667        0.723750     0.721123  0.722434
# 7  0.250000        0.720239     0.770377  0.744465
# 4  0.291262        0.745188     0.767177  0.756023
# 8  0.255814        0.745088     0.770327  0.757497
# 0  0.400000        0.787436     0.741684  0.763876
# 2  0.311688        0.756980     0.773840  0.765317
# 5  0.266667        0.767407     0.763859  0.765629
# 3  0.484848        0.806274     0.817078  0.811640
# 9  0.372881        0.821048     0.827028  0.824027
# 1  0.640000        0.909303     0.884107  0.896528

# %%
experiment_data = tqdm(df_test['zdanie_nieformalne'].tolist()[:150])
model_predictions = [
        formalize(input)
        for input in experiment_data
    ]
# Out:
#   0%|          | 0/150 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.

# %%
import mlflow
import dagshub

dagshub.init(repo_owner="informal2formal", repo_name="mlflow", mlflow=True)

run_name = "PLLuM Huggingface Trained"

mlflow.set_experiment(run_name)

with mlflow.start_run(run_name=run_name):
    mlflow.log_param("base_model_name", repo_id)
    mlflow.log_param("prompt_template", system_message)
    mlflow.log_param("dataset_uri", dataset_uri)

    # Test dataset evaluation using `Evaluator`
    evaluate_df_metrics, avg_metrics = evaluate_language_model(
        model_predictions, experiment_data
    )
    mlflow.log_metrics(avg_metrics)

mlflow.end_run()
# Out:
# Initialized MLflow to track repo "informal2formal/mlflow"
# Repository informal2formal/mlflow initialized!
# Computing ROUGE scores:   0%|          | 0/150 [00:00<?, ?it/s]
#
# Computing ROUGE scores:   1%|▏         | 2/150 [00:00<00:12, 12.18it/s]
#
# Computing ROUGE scores:   3%|▎         | 4/150 [00:00<00:17,  8.43it/s]
#
# Computing ROUGE scores:   3%|▎         | 5/150 [00:00<00:18,  7.96it/s]
#
# Computing ROUGE scores:   4%|▍         | 6/150 [00:00<00:19,  7.55it/s]
#
# Computing ROUGE scores:   5%|▍         | 7/150 [00:00<00:23,  6.17it/s]
#
# Computing ROUGE scores:   5%|▌         | 8/150 [00:01<00:22,  6.39it/s]
#
# Computing ROUGE scores:   6%|▌         | 9/150 [00:01<00:21,  6.51it/s]
#
# Computing ROUGE scores:   7%|▋         | 10/150 [00:01<00:21,  6.60it/s]
#
# Computing ROUGE scores:   7%|▋         | 11/150 [00:01<00:20,  6.65it/s]
#
# Computing ROUGE scores:   8%|▊         | 12/150 [00:01<00:20,  6.59it/s]
#
# Computing ROUGE scores:   9%|▊         | 13/150 [00:01<00:20,  6.62it/s]
#
# Computing ROUGE scores:   9%|▉         | 14/150 [00:02<00:22,  6.03it/s]
#
# Computing ROUGE scores:  10%|█         | 15/150 [00:02<00:22,  6.09it/s]
#
# Computing ROUGE scores:  11%|█         | 16/150 [00:02<00:22,  6.01it/s]
#
# Computing ROUGE scores:  11%|█▏        | 17/150 [00:02<00:21,  6.27it/s]
#
# Computing ROUGE scores:  12%|█▏        | 18/150 [00:02<00:21,  6.18it/s]
#
# Computing ROUGE scores:  13%|█▎        | 19/150 [00:02<00:20,  6.46it/s]
#
# Computing ROUGE scores:  13%|█▎        | 20/150 [00:03<00:21,  5.95it/s]
#
# Computing ROUGE scores:  14%|█▍        | 21/150 [00:03<00:20,  6.15it/s]
#
# Computing ROUGE scores:  15%|█▍        | 22/150 [00:03<00:20,  6.34it/s]
#
# Computing ROUGE scores:  15%|█▌        | 23/150 [00:03<00:19,  6.48it/s]
#
# Computing ROUGE scores:  16%|█▌        | 24/150 [00:03<00:19,  6.61it/s]
#
# Computing ROUGE scores:  17%|█▋        | 25/150 [00:03<00:19,  6.56it/s]
#
# Computing ROUGE scores:  17%|█▋        | 26/150 [00:03<00:18,  6.83it/s]
#
# Computing ROUGE scores:  18%|█▊        | 27/150 [00:04<00:21,  5.74it/s]
#
# Computing ROUGE scores:  19%|█▊        | 28/150 [00:04<00:20,  6.08it/s]
#
# Computing ROUGE scores:  19%|█▉        | 29/150 [00:04<00:19,  6.35it/s]
#
# Computing ROUGE scores:  20%|██        | 30/150 [00:04<00:18,  6.43it/s]
#
# Computing ROUGE scores:  21%|██        | 31/150 [00:04<00:18,  6.38it/s]
#
# Computing ROUGE scores:  21%|██▏       | 32/150 [00:04<00:18,  6.55it/s]
#
# Computing ROUGE scores:  22%|██▏       | 33/150 [00:05<00:18,  6.45it/s]
#
# Computing ROUGE scores:  23%|██▎       | 34/150 [00:05<00:18,  6.15it/s]
#
# Computing ROUGE scores:  23%|██▎       | 35/150 [00:05<00:18,  6.26it/s]
#
# Computing ROUGE scores:  24%|██▍       | 36/150 [00:05<00:18,  6.32it/s]
#
# Computing ROUGE scores:  25%|██▍       | 37/150 [00:05<00:17,  6.44it/s]
#
# Computing ROUGE scores:  25%|██▌       | 38/150 [00:05<00:17,  6.28it/s]
#
# Computing ROUGE scores:  26%|██▌       | 39/150 [00:06<00:18,  5.90it/s]
#
# Computing ROUGE scores:  27%|██▋       | 40/150 [00:06<00:17,  6.13it/s]
#
# Computing ROUGE scores:  27%|██▋       | 41/150 [00:06<00:17,  6.31it/s]
#
# Computing ROUGE scores:  28%|██▊       | 42/150 [00:06<00:16,  6.37it/s]
#
# Computing ROUGE scores:  29%|██▊       | 43/150 [00:06<00:16,  6.44it/s]
#
# Computing ROUGE scores:  29%|██▉       | 44/150 [00:06<00:16,  6.61it/s]
#
# Computing ROUGE scores:  30%|███       | 45/150 [00:06<00:17,  6.14it/s]
#
# Computing ROUGE scores:  31%|███       | 46/150 [00:07<00:19,  5.47it/s]
#
# Computing ROUGE scores:  31%|███▏      | 47/150 [00:07<00:19,  5.16it/s]
#
# Computing ROUGE scores:  32%|███▏      | 48/150 [00:07<00:20,  5.04it/s]
#
# Computing ROUGE scores:  33%|███▎      | 49/150 [00:07<00:20,  5.00it/s]
#
# Computing ROUGE scores:  33%|███▎      | 50/150 [00:08<00:20,  4.80it/s]
#
# Computing ROUGE scores:  34%|███▍      | 51/150 [00:08<00:21,  4.64it/s]
#
# Computing ROUGE scores:  35%|███▍      | 52/150 [00:08<00:21,  4.61it/s]
#
# Computing ROUGE scores:  35%|███▌      | 53/150 [00:08<00:20,  4.64it/s]
#
# Computing ROUGE scores:  36%|███▌      | 54/150 [00:08<00:20,  4.60it/s]
#
# Computing ROUGE scores:  37%|███▋      | 55/150 [00:09<00:20,  4.66it/s]
#
# Computing ROUGE scores:  37%|███▋      | 56/150 [00:09<00:19,  4.74it/s]
#
# Computing ROUGE scores:  38%|███▊      | 57/150 [00:09<00:20,  4.58it/s]
#
# Computing ROUGE scores:  39%|███▊      | 58/150 [00:09<00:20,  4.50it/s]
#
# Computing ROUGE scores:  39%|███▉      | 59/150 [00:10<00:21,  4.28it/s]
#
# Computing ROUGE scores:  40%|████      | 60/150 [00:10<00:21,  4.23it/s]
#
# Computing ROUGE scores:  41%|████      | 61/150 [00:10<00:20,  4.31it/s]
#
# Computing ROUGE scores:  41%|████▏     | 62/150 [00:10<00:18,  4.79it/s]
#
# Computing ROUGE scores:  42%|████▏     | 63/150 [00:10<00:17,  5.07it/s]
#
# Computing ROUGE scores:  43%|████▎     | 64/150 [00:11<00:17,  4.90it/s]
#
# Computing ROUGE scores:  43%|████▎     | 65/150 [00:11<00:16,  5.26it/s]
#
# Computing ROUGE scores:  44%|████▍     | 66/150 [00:11<00:14,  5.64it/s]
#
# Computing ROUGE scores:  45%|████▍     | 67/150 [00:11<00:14,  5.82it/s]
#
# Computing ROUGE scores:  45%|████▌     | 68/150 [00:11<00:13,  6.05it/s]
#
# Computing ROUGE scores:  46%|████▌     | 69/150 [00:11<00:13,  6.04it/s]
#
# Computing ROUGE scores:  47%|████▋     | 70/150 [00:12<00:14,  5.39it/s]
#
# Computing ROUGE scores:  47%|████▋     | 71/150 [00:12<00:14,  5.56it/s]
#
# Computing ROUGE scores:  48%|████▊     | 72/150 [00:12<00:13,  5.75it/s]
#
# Computing ROUGE scores:  49%|████▊     | 73/150 [00:12<00:12,  6.05it/s]
#
# Computing ROUGE scores:  49%|████▉     | 74/150 [00:12<00:12,  6.24it/s]
#
# Computing ROUGE scores:  50%|█████     | 75/150 [00:12<00:11,  6.35it/s]
#
# Computing ROUGE scores:  51%|█████     | 76/150 [00:13<00:12,  5.77it/s]
#
# Computing ROUGE scores:  51%|█████▏    | 77/150 [00:13<00:12,  5.62it/s]
#
# Computing ROUGE scores:  52%|█████▏    | 78/150 [00:13<00:12,  5.59it/s]
#
# Computing ROUGE scores:  53%|█████▎    | 79/150 [00:13<00:12,  5.90it/s]
#
# Computing ROUGE scores:  53%|█████▎    | 80/150 [00:13<00:11,  6.00it/s]
#
# Computing ROUGE scores:  54%|█████▍    | 81/150 [00:13<00:10,  6.29it/s]
#
# Computing ROUGE scores:  55%|█████▍    | 82/150 [00:14<00:12,  5.60it/s]
#
# Computing ROUGE scores:  55%|█████▌    | 83/150 [00:14<00:11,  5.69it/s]
#
# Computing ROUGE scores:  56%|█████▌    | 84/150 [00:14<00:11,  5.84it/s]
#
# Computing ROUGE scores:  57%|█████▋    | 85/150 [00:14<00:10,  6.11it/s]
#
# Computing ROUGE scores:  57%|█████▋    | 86/150 [00:14<00:10,  6.31it/s]
#
# Computing ROUGE scores:  58%|█████▊    | 87/150 [00:14<00:09,  6.31it/s]
#
# Computing ROUGE scores:  59%|█████▊    | 88/150 [00:15<00:10,  6.08it/s]
#
# Computing ROUGE scores:  59%|█████▉    | 89/150 [00:15<00:10,  5.88it/s]
#
# Computing ROUGE scores:  60%|██████    | 90/150 [00:15<00:09,  6.00it/s]
#
# Computing ROUGE scores:  61%|██████    | 91/150 [00:15<00:09,  6.15it/s]
#
# Computing ROUGE scores:  61%|██████▏   | 92/150 [00:15<00:09,  6.23it/s]
#
# Computing ROUGE scores:  62%|██████▏   | 93/150 [00:15<00:08,  6.45it/s]
#
# Computing ROUGE scores:  63%|██████▎   | 94/150 [00:16<00:09,  5.80it/s]
#
# Computing ROUGE scores:  63%|██████▎   | 95/150 [00:16<00:09,  5.74it/s]
#
# Computing ROUGE scores:  64%|██████▍   | 96/150 [00:16<00:09,  5.84it/s]
#
# Computing ROUGE scores:  65%|██████▍   | 97/150 [00:16<00:08,  6.07it/s]
#
# Computing ROUGE scores:  65%|██████▌   | 98/150 [00:16<00:08,  6.10it/s]
#
# Computing ROUGE scores:  66%|██████▌   | 99/150 [00:16<00:07,  6.38it/s]
#
# Computing ROUGE scores:  67%|██████▋   | 100/150 [00:17<00:08,  6.17it/s]
#
# Computing ROUGE scores:  67%|██████▋   | 101/150 [00:17<00:07,  6.15it/s]
#
# Computing ROUGE scores:  68%|██████▊   | 102/150 [00:17<00:07,  6.07it/s]
#
# Computing ROUGE scores:  69%|██████▊   | 103/150 [00:17<00:07,  6.08it/s]
#
# Computing ROUGE scores:  69%|██████▉   | 104/150 [00:17<00:07,  6.22it/s]
#
# Computing ROUGE scores:  70%|███████   | 105/150 [00:17<00:07,  6.40it/s]
#
# Computing ROUGE scores:  71%|███████   | 106/150 [00:18<00:07,  6.08it/s]
#
# Computing ROUGE scores:  71%|███████▏  | 107/150 [00:18<00:06,  6.16it/s]
#
# Computing ROUGE scores:  72%|███████▏  | 108/150 [00:18<00:06,  6.04it/s]
#
# Computing ROUGE scores:  73%|███████▎  | 109/150 [00:18<00:06,  6.27it/s]
#
# Computing ROUGE scores:  73%|███████▎  | 110/150 [00:18<00:06,  6.21it/s]
#
# Computing ROUGE scores:  74%|███████▍  | 111/150 [00:18<00:06,  6.42it/s]
#
# Computing ROUGE scores:  75%|███████▍  | 112/150 [00:19<00:06,  6.24it/s]
#
# Computing ROUGE scores:  75%|███████▌  | 113/150 [00:19<00:05,  6.35it/s]
#
# Computing ROUGE scores:  76%|███████▌  | 114/150 [00:19<00:05,  6.18it/s]
#
# Computing ROUGE scores:  77%|███████▋  | 115/150 [00:19<00:05,  6.18it/s]
#
# Computing ROUGE scores:  77%|███████▋  | 116/150 [00:19<00:05,  6.27it/s]
#
# Computing ROUGE scores:  78%|███████▊  | 117/150 [00:19<00:05,  6.37it/s]
#
# Computing ROUGE scores:  79%|███████▊  | 118/150 [00:19<00:05,  6.07it/s]
#
# Computing ROUGE scores:  79%|███████▉  | 119/150 [00:20<00:05,  6.16it/s]
#
# Computing ROUGE scores:  80%|████████  | 120/150 [00:20<00:04,  6.27it/s]
#
# Computing ROUGE scores:  81%|████████  | 121/150 [00:20<00:04,  6.10it/s]
#
# Computing ROUGE scores:  81%|████████▏ | 122/150 [00:20<00:05,  5.55it/s]
#
# Computing ROUGE scores:  82%|████████▏ | 123/150 [00:20<00:05,  5.21it/s]
#
# Computing ROUGE scores:  83%|████████▎ | 124/150 [00:21<00:05,  5.05it/s]
#
# Computing ROUGE scores:  83%|████████▎ | 125/150 [00:21<00:05,  4.88it/s]
#
# Computing ROUGE scores:  84%|████████▍ | 126/150 [00:21<00:05,  4.78it/s]
#
# Computing ROUGE scores:  85%|████████▍ | 127/150 [00:21<00:04,  4.78it/s]
#
# Computing ROUGE scores:  85%|████████▌ | 128/150 [00:21<00:04,  4.71it/s]
#
# Computing ROUGE scores:  86%|████████▌ | 129/150 [00:22<00:04,  4.71it/s]
#
# Computing ROUGE scores:  87%|████████▋ | 130/150 [00:22<00:04,  4.70it/s]
#
# Computing ROUGE scores:  87%|████████▋ | 131/150 [00:22<00:04,  4.59it/s]
#
# Computing ROUGE scores:  88%|████████▊ | 132/150 [00:22<00:03,  4.63it/s]
#
# Computing ROUGE scores:  89%|████████▊ | 133/150 [00:23<00:03,  4.65it/s]
#
# Computing ROUGE scores:  89%|████████▉ | 134/150 [00:23<00:03,  4.55it/s]
#
# Computing ROUGE scores:  90%|█████████ | 135/150 [00:23<00:03,  4.49it/s]
#
# Computing ROUGE scores:  91%|█████████ | 136/150 [00:23<00:03,  4.34it/s]
#
# Computing ROUGE scores:  91%|█████████▏| 137/150 [00:24<00:02,  4.36it/s]
#
# Computing ROUGE scores:  92%|█████████▏| 138/150 [00:24<00:02,  4.81it/s]
#
# Computing ROUGE scores:  93%|█████████▎| 139/150 [00:24<00:02,  5.16it/s]
#
# Computing ROUGE scores:  93%|█████████▎| 140/150 [00:24<00:01,  5.48it/s]
#
# Computing ROUGE scores:  94%|█████████▍| 141/150 [00:24<00:01,  5.82it/s]
#
# Computing ROUGE scores:  95%|█████████▍| 142/150 [00:24<00:01,  5.87it/s]
#
# Computing ROUGE scores:  95%|█████████▌| 143/150 [00:25<00:01,  5.21it/s]
#
# Computing ROUGE scores:  96%|█████████▌| 144/150 [00:25<00:01,  5.39it/s]
#
# Computing ROUGE scores:  97%|█████████▋| 145/150 [00:25<00:00,  5.63it/s]
#
# Computing ROUGE scores:  97%|█████████▋| 146/150 [00:25<00:00,  5.85it/s]
#
# Computing ROUGE scores:  98%|█████████▊| 147/150 [00:25<00:00,  5.81it/s]
#
# Computing ROUGE scores:  99%|█████████▊| 148/150 [00:25<00:00,  5.93it/s]
#
# Computing ROUGE scores:  99%|█████████▉| 149/150 [00:26<00:00,  6.08it/s]
#
# Computing ROUGE scores: 100%|██████████| 150/150 [00:26<00:00,  5.70it/s]
#
#
# Computing BERT scores:   0%|          | 0/150 [00:00<?, ?it/s]
#
# Computing BERT scores:   1%|▏         | 2/150 [00:01<01:30,  1.64it/s]
#
# Computing BERT scores:   4%|▍         | 6/150 [00:01<00:25,  5.57it/s]
#
# Computing BERT scores:   7%|▋         | 11/150 [00:01<00:12, 10.99it/s]
#
# Computing BERT scores:  11%|█         | 16/150 [00:01<00:08, 16.61it/s]
#
# Computing BERT scores:  14%|█▍        | 21/150 [00:01<00:05, 21.99it/s]
#
# Computing BERT scores:  18%|█▊        | 27/150 [00:01<00:04, 28.35it/s]
#
# Computing BERT scores:  21%|██▏       | 32/150 [00:01<00:03, 32.65it/s]
#
# Computing BERT scores:  25%|██▍       | 37/150 [00:02<00:03, 36.61it/s]
#
# Computing BERT scores:  28%|██▊       | 42/150 [00:02<00:02, 39.33it/s]
#
# Computing BERT scores:  31%|███▏      | 47/150 [00:02<00:02, 41.10it/s]
#
# Computing BERT scores:  35%|███▍      | 52/150 [00:02<00:02, 42.97it/s]
#
# Computing BERT scores:  38%|███▊      | 57/150 [00:02<00:02, 43.81it/s]
#
# Computing BERT scores:  42%|████▏     | 63/150 [00:02<00:01, 45.62it/s]
#
# Computing BERT scores:  45%|████▌     | 68/150 [00:02<00:01, 45.56it/s]
#
# Computing BERT scores:  49%|████▊     | 73/150 [00:02<00:01, 46.52it/s]
#
# Computing BERT scores:  52%|█████▏    | 78/150 [00:02<00:01, 46.76it/s]
#
# Computing BERT scores:  55%|█████▌    | 83/150 [00:02<00:01, 47.35it/s]
#
# Computing BERT scores:  59%|█████▊    | 88/150 [00:03<00:01, 47.90it/s]
#
# Computing BERT scores:  63%|██████▎   | 94/150 [00:03<00:01, 48.88it/s]
#
# Computing BERT scores:  67%|██████▋   | 100/150 [00:03<00:01, 49.59it/s]
#
# Computing BERT scores:  70%|███████   | 105/150 [00:03<00:00, 48.15it/s]
#
# Computing BERT scores:  73%|███████▎  | 110/150 [00:03<00:00, 47.89it/s]
#
# Computing BERT scores:  77%|███████▋  | 115/150 [00:03<00:00, 47.43it/s]
#
# Computing BERT scores:  80%|████████  | 120/150 [00:03<00:00, 47.07it/s]
#
# Computing BERT scores:  83%|████████▎ | 125/150 [00:03<00:00, 47.67it/s]
#
# Computing BERT scores:  87%|████████▋ | 131/150 [00:03<00:00, 48.87it/s]
#
# Computing BERT scores:  91%|█████████▏| 137/150 [00:04<00:00, 49.76it/s]
#
# Computing BERT scores:  95%|█████████▌| 143/150 [00:04<00:00, 49.97it/s]
#
# Computing BERT scores: 100%|██████████| 150/150 [00:04<00:00, 34.30it/s]
# 🏃 View run PLLuM Huggingface Trained at: https://dagshub.com/informal2formal/mlflow.mlflow/#/experiments/9/runs/4d7b6c9fd06a4d3f88f38de31277e6e1
# 🧪 View experiment at: https://dagshub.com/informal2formal/mlflow.mlflow/#/experiments/9

# %%
trainer.save_model('informal-to-formal-text-converter-final')

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r informal-to-formal-text-converter-model/ drive/MyDrive/PLLuM-trained/

# %%
model.save_pretrained(run_name)
tokenizer.save_pretrained(run_name)
# Out:
# ('PLLuM Huggingface Trained/tokenizer_config.json',
#  'PLLuM Huggingface Trained/special_tokens_map.json',
#  'PLLuM Huggingface Trained/tokenizer.json')
